# %%
from ibapi.client import EClient
from ibapi.wrapper import EWrapper
import time
import threading
import os

# os.chdir("C:\\Users\\Yodyium\\Desktop\\Work\\Courses\\204496 Computationa Finance\\Interactive Brokers API python")

class TradeApp(EWrapper, EClient):
    def __init__(self):
        EClient.__init__(self, self) 
    
    def scannerParameters(self, xml):
        super().scannerParameters(xml)
        open('scanner_params.xml', 'w').write(xml)
        print("ScannerParameters received.")

def websocket_con():
    app.run()
    
app = TradeApp()
app.connect(host='127.0.0.1', port=7497, clientId=45) #port 4002 for ib gateway paper trading/7497 for TWS paper trading

con_thread = threading.Thread(target=websocket_con, daemon=True)
con_thread.start()
time.sleep(1) # some latency added to ensure that the connection is established

app.reqScannerParameters()
# Out:
# ERROR -1 1751099497861 2104 Market data farm connection is OK:usfarm.nj
# ERROR -1 1751099497861 2104 Market data farm connection is OK:usfuture
# ERROR -1 1751099497861 2104 Market data farm connection is OK:usopt.nj
# ERROR -1 1751099497861 2104 Market data farm connection is OK:cashfarm
# ERROR -1 1751099497861 2104 Market data farm connection is OK:usfarm
# ERROR -1 1751099497861 2106 HMDS data farm connection is OK:ushmds
# ERROR -1 1751099497862 2158 Sec-def data farm connection is OK:secdefnj
# ScannerParameters received.
# ERROR -1 1751101168619 1100 Connectivity between IBKR and Trader Workstation has been lost.
# ERROR -1 1751101184232 2103 Market data farm connection is broken:cashfarm
# ERROR -1 1751101184522 2103 Market data farm connection is broken:usfuture
# ERROR -1 1751101185047 2103 Market data farm connection is broken:usopt.nj
# ERROR -1 1751103281191 2103 Market data farm connection is broken:usfarm
# ...
